# %% [markdown]
# # ETL (Excel)
#
# **Author**: Cleverson Matiolli, PhD
# **Company**: AidBio
#
# This notebook is designed to extract, transform and load relevant data points from excel files.

# %% [markdown]
# ## Imports
